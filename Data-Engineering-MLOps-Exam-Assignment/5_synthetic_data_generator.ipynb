# %%
import os

#Loading Togehter.ai API
TOGETHER_API_KEY = os.environ["TOGETHER_API_KEY"]

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from langchain_together import Together

# Initialize Faker for generating random user and beer names
fake = Faker()

# Initialize the language model for generating reviews
llm = Together(
    model="teknium/OpenHermes-2p5-Mistral-7B",
    temperature=0.3,
    max_tokens=256,
    top_k=50,
    # together_api_key="YOUR_API_KEY"
)

def generate_beer_review(style):
    """ Generates a detailed beer review using the Together AI model. """
    prompt = f"Generate a detailed beer review for a {style}. Describe its appearance, aroma, taste, and overall impressions in a cohesive manner. Draw inspiration from the following examples:\n\n1. On tap at the Springfield, PA location. Poured a deep and cloudy orange (almost a copper) color with a small sized off white head. Aromas of oranges and all around citric. Tastes of oranges, light caramel, and a very light grapefruit finish. Light lacing left on the glass.\n\n2. On tap at the John Harvards in Springfield PA. Pours a ruby red amber with a medium off white creamy head that left light lacing. Aroma of orange and various other citrus. Flavor of pine, orange, grapefruit, and some malt balance. Very light bitterness for the 80+ IBUs they said this one had.\n\n3. UPDATED: FEB 19, 2003 Springfield, PA. I've never had the Budvar Cristal but this is exactly what I imagined it to be. A clean and refreshing, hoppy beer, medium-bodied with plenty of flavor. This beer's only downfall is an unpleasant bitterness in the aftertaste.\n\n4. On tap at the Springfield PA location billed as the 'Fancy Lawnmower Light'. Pours a translucent clear yellow with a small bubbly white head. Aroma was lightly sweet and malty, really no hop presence. Flavor was light, grainy, grassy, and malty. Just really light in flavor and aroma overall. Watery.\n\n5. On tap at the Springfield, PA location. Poured a lighter golden color with a very small, if any head. Aromas and tastes of grain, very lightly fruity with a light grassy finish. Lively yet thin and watery body. Oh yeah, the person seating me told me this was a new one and was a Pale Ale even though the menu he gave me listed it as a lighter beer brewed in the Kölsch style.\n\n6. Sampled @ the Springfield, PA location. Candi Sugar dominates this Belgian Ale. Beer was on the flat side but had a nice crimson color. Enjoyable Belgian Ale, I did not expect John Harvards to have it in its lineup.\n\n7. Springfield... Poured a hazy copper color with a medium-sized, off white head that left spotty lacing on the glass. Aroma of yeast, dried fruits, clove, banana, and cherries, with light roastiness. Aroma was very dubbelish. Herbal taste of dark fruits, yeast, and alcohol was barely noticed. Slick mouthfeel. Could have been more flavorful.\n\n8. UPDATED: FEB 19, 2003 Springfield, PA. Darkish copper colored, with no head - probably poured like that on purpose. Served inappropriately at about 40 deg F. This beer was cold. It tasted fine at that temp but I had to let it warm up for a while. It was worth the wait, as a very interesting and complex character developed. Very phenolic and funky - with a strong ester of bubblegum. Also a little clove or some kind of spice. Strong but not overwhelming at all. Surprisingly easy to drink.\n\n9. UPDATED: FEB 19, 2003 Springfield, PA. Sharp and cloyingly sweet. The alcohol presence becomes more and more noticeable. From Springfield PA: nice smooth malty flavor, mildly fruity, but served via nitro and thru a restrictor disc (stout tap). Thus, overly creamy and lacking some of its original flavor. I could tell there was a pretty good beer in there. Aroma difficult to detect.\n\nProvide your own detailed review, focusing on key aspects like appearance, aroma, taste, and overall impressions."
    response = llm.invoke(prompt)
    return response

def generate_beers(n):
    """ Generates a list of beers with random attributes. """
    return [{'beer_name': fake.word(),
             'beer_beerid': fake.uuid4(),
             'beer_brewerid': random.randint(1000, 9999),
             'beer_abv': round(random.uniform(3.0, 12.0), 1),
             'beer_style': random.choice(['IPA', 'Stout', 'Lager', 'Ale', 'Porter'])} for _ in range(n)]

def generate_reviewer_profiles(n):
    """ Generates a list of reviewer profiles. """
    return [{'reviewer_id': fake.uuid4(), 'username': fake.user_name()} for _ in range(n)]

def generate_reviews(beers, reviewer_profiles, num_reviews):
    """ Generates a DataFrame containing reviews for the beers. """
    reviews = []
    for _ in range(num_reviews):
        beer = random.choice(beers)
        reviewer = random.choice(reviewer_profiles)
        review_text = generate_beer_review(beer['beer_style'])
        reviews.append({
            'beer_name': beer['beer_name'],
            'beer_beerid': beer['beer_beerid'],
            'beer_brewerid': beer['beer_brewerid'],
            'beer_abv': beer['beer_abv'],
            'beer_style': beer['beer_style'],
            'review_appearance': np.random.randint(1, 10),
            'review_aroma': np.random.randint(1, 10),
            'review_palate': np.random.randint(1, 10),
            'review_taste': np.random.randint(1, 10),
            'review_overall': np.random.randint(1, 10),
            'review_time': fake.date_time_this_year().strftime('%Y-%m-%d %H:%M:%S'),
            'review_profilename': reviewer['username'],
            'review_text': review_text
        })
    return pd.DataFrame(reviews)

# Example usage
num_beers = 10
num_reviewers = 10
num_reviews = 10

beers = generate_beers(num_beers)
reviewer_profiles = generate_reviewer_profiles(num_reviewers)
reviews_df = generate_reviews(beers, reviewer_profiles, num_reviews)

reviews_df.to_csv('reviews.csv', index=False)

print(reviews_df.head())
# Out:
#   beer_name                           beer_beerid  beer_brewerid  beer_abv  \
# 0      onto  b20ef6dd-851a-4747-b39b-d09f16d72400           1300       6.6
# 1      left  44692c88-8fce-44c5-8d5f-2e44e36cad24           1590       7.8
# 2      left  44692c88-8fce-44c5-8d5f-2e44e36cad24           1590       7.8
# 3    theory  a21c1ff8-f53e-445e-8ca3-cb51474b4761           9620      10.7
# 4    season  8c4e408f-a895-40e9-bfd7-95802f07144d           8358       5.4
#
#   beer_style  review_appearance  review_aroma  review_palate  review_taste  \
# 0      Stout                  8             6              9             6
# 1      Lager                  1             9              5             6
# 2      Lager                  6             2              9             7
# 3        IPA                  9             7              8             8
# 4      Lager                  9             2              1             6
#
#    review_overall          review_time review_profilename  \
# 0               5  2024-05-01 00:34:50          sstephens
# 1               6  2024-03-23 02:56:22            bryan95
# 2               7  2024-04-30 11:23:33          oespinoza
# 3               6  2024-02-29 23:53:50            bryan95
# 4               3  2024-01-14 12:03:52       davidfleming
#
#                                          review_text
# 0  \n\nAppearance: The Stout pours a deep, dark b...
# 1  \n\nAppearance: The lager pours a deep golden ...
# 2  \n\nAppearance: The lager pours a deep golden ...
# 3  \n\nAppearance: The IPA pours a deep golden co...
# 4  \n\nAppearance: The lager pours a crystal clea...

# %%
# Inspecting the results 
for review in reviews_df['review_text'][:10]:
    print(review)
    print('\n')
# Out:
# Beer Review: Porter
#
# The Porter I sampled at the Springfield, PA location was a true delight. Upon pouring, it revealed a deep, dark brown color with a rich, creamy tan head that left behind beautiful lacing on the glass. The aroma was rich and inviting, with notes of roasted malt, chocolate, and a hint of coffee.
#
# As I took my first sip, I was greeted with a smooth, velvety mouthfeel that was perfectly balanced between the roasted malts and the subtle hop presence. The taste was complex, offering flavors of dark chocolate, coffee, and a touch of caramel. The finish was clean and slightly bitter, leaving me wanting another sip.
#
# Overall, this Porter was an excellent example of the style. It was well-balanced, flavorful, and had a smooth, creamy texture that made it enjoyable from start to finish. I highly recommend seeking out this Porter for anyone who appreciates a well-crafted dark beer.
#
#
#
#
# Appearance: The lager pours a clear, golden yellow color with a small, white head that leaves some spotty lacing on the glass.
#
# Aroma: The aroma of this lager is quite subtle, with hints of grain, light fruit, and a slight hoppiness.
#
# Taste: The taste of this lager is crisp and refreshing, with a light maltiness and a hint of bitterness from the hops. It has a clean finish and is easy to drink.
#
# Overall Impressions: This lager is a great choice for those who enjoy a light, refreshing beer. It is perfect for sipping on a hot summer day or pairing with light, summery foods. While it may not have a lot of complexity, it is a well-balanced beer that is enjoyable to drink.
#
#
#
#
# Appearance: The ale pours a deep amber color with a thick, creamy head that leaves behind sticky lacing on the glass. It has a clear and bright appearance, inviting the drinker to take a sip.
#
# Aroma: The aroma of this ale is dominated by a mix of citrus and pine, with hints of caramel and toffee. The hops are prominent, but not overpowering, and create a pleasant and inviting scent.
#
# Taste: The taste of this ale is well-balanced, with a slight bitterness from the hops that is complemented by the sweetness of the malts. The citrus and pine flavors from the aroma come through in the taste, creating a refreshing and crisp drinking experience.
#
# Overall Impressions: This ale is a great example of a well-crafted and balanced beer. The combination of citrus and pine flavors, along with the sweetness of the malts, creates a complex and enjoyable drinking experience. The appearance of the beer is also inviting, with a clear and bright amber color and a thick, creamy head. Overall, this is a beer that
#
#
#
#
# Appearance: The Porter pours a deep, dark brown color with a thick, creamy tan head that leaves behind sticky lacing on the glass.
#
# Aroma: The aroma of this Porter is rich and complex, with notes of roasted malts, chocolate, and coffee. There's also a hint of sweetness and a subtle fruity undertone.
#
# Taste: The taste of this Porter is smooth and velvety, with a rich and robust flavor profile. The roasted malts dominate the palate, followed by a hint of chocolate and coffee. There's also a slight bitterness that balances out the sweetness, making for a well-rounded and satisfying taste.
#
# Overall Impressions: This Porter is a true delight for beer enthusiasts who appreciate the darker, richer styles. It's a great choice for sipping on a cool evening or pairing with hearty meals. The combination of roasted malts, chocolate, and coffee flavors make it a complex and satisfying beer that's sure to impress.
#
#
#
#
# Appearance: The Porter pours a deep, dark brown color with a thick, creamy tan head that leaves a nice amount of lacing on the glass.
#
# Aroma: The aroma of this Porter is rich and inviting, with notes of roasted malt, chocolate, and a hint of coffee.
#
# Taste: The taste of this Porter is smooth and well-balanced, with flavors of roasted malt, chocolate, and a subtle hint of coffee. The bitterness is present but not overpowering, allowing the malt flavors to shine through.
#
# Overall Impressions: This Porter is a great example of the style, with a rich and complex flavor profile that is both smooth and satisfying. The aroma is inviting, and the overall balance of flavors makes this a beer that can be enjoyed by both novice and experienced beer drinkers alike. It is a great choice for those who enjoy darker beers with a rich, malty flavor.
#
#
#
#
# Appearance: The lager pours a clear golden color with a small, frothy white head that leaves some lacing on the glass.
#
# Aroma: The aroma of this lager is quite pleasant, with notes of fresh grain, light citrus, and a hint of floral hops.
#
# Taste: The taste of this lager is well-balanced, with a crisp, refreshing flavor that showcases the malt and hops in equal measure. There's a subtle sweetness upfront, followed by a clean, bitter finish that lingers pleasantly on the palate.
#
# Overall Impressions: This lager is a true delight to drink, offering a perfect balance of flavor and refreshment. It's light enough to enjoy on a warm day, yet complex enough to satisfy even the most discerning beer enthusiast. Highly recommended for those who appreciate a well-crafted lager.
#
#
#
#
# Review:
#
# The Porter I sampled at the Springfield, PA location poured a deep, dark brown color with a thick, creamy tan head that left substantial lacing on the glass. The aroma was rich and complex, with notes of roasted malt, dark chocolate, and a hint of smokiness.
#
# Upon taking a sip, I was greeted with a smooth, velvety mouthfeel and a well-balanced flavor profile. The roasted malt and chocolate notes were present, but not overpowering, allowing the subtle nuances of caramel and toffee to shine through. A slight hop bitterness provided a pleasant counterpoint to the sweetness of the malt, creating a harmonious balance.
#
# Overall, this Porter was an excellent example of the style, showcasing the depth and complexity that can be achieved through careful brewing and attention to detail. It was a delight to drink and left me wanting more. I highly recommend seeking out this Porter for those who enjoy well-crafted dark beers.
#
#
#
#
# Beer Review: Lager
#
# On tap at the Springfield, PA location, this Lager pours a deep golden color with a small-sized, off-white head that leaves light lacing on the glass. The aroma is dominated by a mix of floral and fruity notes, with hints of citrus and a subtle maltiness.
#
# Taking a sip, the taste is well-balanced between the crisp, refreshing hops and the sweet, malty undertones. A slight bitterness lingers in the aftertaste, which adds to the overall complexity of the beer. The carbonation is moderate, providing a smooth mouthfeel without being overly effervescent.
#
# Overall, this Lager is a great example of the style, offering a clean and refreshing drinking experience with just enough flavor to keep things interesting. It would be an excellent choice for those looking for a session beer on a warm day or as a palate cleanser between heavier beers. Highly recommended for Lager enthusiasts and newcomers alike.
#
#
#
#
# ## Appearance
#
# The lager pours a bright golden color with a small, frothy white head that persists throughout the drinking experience. The carbonation is moderate, creating a pleasant effervescence that adds to the overall visual appeal. The body is clear and bright, with no cloudiness or sediment present.
#
# ## Aroma
#
# The aroma of this lager is subtle yet inviting, with a hint of sweet malt and a touch of floral hops. There is no overpowering scent, but rather a delicate balance that entices the drinker to take a sip.
#
# ## Taste
#
# Upon taking a sip, the initial flavor is a crisp, clean maltiness that gives way to a subtle hop bitterness. The beer is well-balanced, with neither the malt nor the hops dominating the taste. The finish is dry and refreshing, leaving a pleasant aftertaste that encourages another sip.
#
# ## Overall Impressions
#
# This lager is a perfect example of the style, offering a refreshing and easy-drinking experience. It is versatile enough to pair well with various foods, making it an excellent choice
#
#
#
#
# Appearance: The ale pours a deep amber color with a frothy, off-white head that leaves a nice lacing on the glass. It has a clear and bright appearance, inviting the drinker to take a sip.
#
# Aroma: The aroma of this ale is dominated by a mix of fruity and floral notes, with a hint of caramel sweetness. The hops are present but not overpowering, providing a nice balance to the overall aroma.
#
# Taste: The taste of this ale is well-balanced, with a mix of malty sweetness and hoppy bitterness. The fruity and floral notes from the aroma are also present in the taste, adding a layer of complexity. The carbonation is moderate, providing a smooth and refreshing mouthfeel.
#
# Overall Impressions: This ale is a well-crafted beer that showcases the best of both malt and hop flavors. It is a great example of a well-balanced ale, with a nice mix of fruity, floral, and caramel notes. The moderate carbonation and smooth mouthfeel make it a great beer for sipping and
